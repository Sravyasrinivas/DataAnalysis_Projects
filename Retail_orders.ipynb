# %%
pip install pathlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ruamel-yaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d ankitbansal06/retail-orders
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 585kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 584kB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile("retail-orders.zip")
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv("orders.csv",na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#rename column names and make them lower case and replace space with underscore
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
#df.columns
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#derive new column discount, sale price and profit

df['discount'] = df['list_price'] * df['discount_percent']/100
#df['discount']
df['sale_price'] = df['list_price'] - df['discount']
#df['sale_price']
df['profit'] = df['sale_price'] - df['cost_price']
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#convert order date from object data type to datetime

df['order_date'] = pd.to_datetime(df['order_date'],format='%Y-%m-%d')
#df.info() or df.dtype()

# %% [markdown]
# The error you're encountering typically occurs when you assign the result of an operation that modifies a DataFrame in place (inplace=True) to a variable, leading the variable to become None. The drop method with inplace=True modifies the DataFrame in place and returns None, so if you assign it back to df, df will become None.

# %%
#drop cost_price,list_price and discount_percent columns

df.drop(columns=['cost_price','list_price','discount_percent'],inplace = True)
df.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
# !pip install pymysql

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-4NP8MPH/DataAnalysis_Projects?driver=SQL+SERVER')
conn= engine.connect()

# %%
##df.to_sql('df_orders', con = conn, index=False, if_exists='replace') 
## if the if_exists is replace it will create its own data types and everything will be set to max whcih will be memory wastage
df.to_sql('df_orders', con = conn, index=False, if_exists='append') 
## if its append then the table DDL is already created and it will just append the values

# %%
 #load the data into mysql using replace option
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError
import pymysql

# Define your database credentials
username = 'root'
password = 'Germany@090413'
host = 'DESKTOP-4NP8MPH'  # e.g., 'localhost' or an IP address
port = 3306  # e.g., 3306
database = 'python'

# Create a connection string
connection_string = f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}'


try:
    # Try to create an SQLAlchemy engine
    engine = create_engine(connection_string)
    
    # Test the connection by executing a query
    with engine.connect() as connection:
        result = connection.execute('SELECT 1')
        print("Connection successful!")

except SQLAlchemyError as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '090413@DESKTOP-4NP8MPH' ([Errno 11003] getaddrinfo failed)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
pymysql.connect(db='python', user='root', passwd='Germany@090413', unix_socket="/tmp/mysql.sock")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7388/1804201891.py in <module>
# ----> 1 pymysql.connect(db='python', user='root', passwd='Germany@090413', unix_socket="/tmp/mysql.sock")
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359             self._sock = None
#     360         else:
# ...

# %%
#load the data into mysql using apend option
df.to_sql('df_orders',con=engine, index = False, if_exists= 'replace')
df_from_sql = pd.read_sql('df_orders', con=engine)
print(df_from_sql)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     648                         try:
# --> 649                             sock = socket.create_connection(
#     650                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# ...
